# %% [markdown]
# * ollama model using OpenAI SDK
# * prompt template
# * langchain

# %%
# use "ollama serve" to start the model

# %%
from openai import OpenAI

client = OpenAI(
    api_key="ollama",  
    base_url="http://localhost:11434/v1"
)

message_temp = [
    {"role":"system", "content":"You're an AI assistant"},
    {"role":"user", "content":"where is the capital of IRAN?"}
]
response = client.chat.completions.create(
    messages= message_temp,
    model="phi"
)

print(response.choices[0].message.content)
# Out:
#  The capital of Iran is Tehran.

# %%
# get query from user

# %%
from openai import OpenAI

client = OpenAI(
    api_key="ollama",  
    base_url="http://localhost:11434/v1"
)


def msg_user(inputs):
    response = client.chat.completions.create(
        messages= [
                    {"role":"system", "content":"You're an AI assistant"},
                    {"role":"user", "content":f"{inputs}"}
                  ],
        model="phi"
    )

    return response.choices[0].message.content

print(msg_user("where is the capital of IRAN?"))
# Out:
#  The capital of Iran is Tehran.

# %%
# use Langchain

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOllama(model="phi")

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You're an Assistant. Answer questions very breifly"),
        ("human", "{input}")
    ]
)

chain = prompt | llm | StrOutputParser()

chain.invoke("where is the capital of IRAN?")
# Out:
# ' The capital city of Iran is Tehran.\n'

# %% [markdown]
# ## summary
#
#
#     * OpenAI
#         .chat.completions.create()
#         model <sting>
#         messages <list of dict>
#         stream  <boolean>
#
#     * Langchain
#         ChatPromptTemplate.from_messages([(<system>),(<human>),(<ai>)])
